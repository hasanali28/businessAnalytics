# %% [markdown]
# ## Exercise 5 Data Cleaning Using Pandas

# %% [markdown]
# ## Question 1
#
# Below we can see that we have a lot of unnecessary text in both columns.  Fortunately, this text is from another coding language, so there is decipherable patterns and information inside the columns.

# %%
import pandas as pd

# %%
towns = pd.read_csv("../data/towns.csv")
towns.head()
# Out:
#                                                State  \
# 0          <td id="LC1" class="blob-code blob-cod...
# 1          <td id="LC1" class="blob-code blob-cod...
# 2          <td id="LC1" class="blob-code blob-cod...
# 3          <td id="LC1" class="blob-code blob-cod...
# 4          <td id="LC1" class="blob-code blob-cod...
#
#                                           RegionName
# 0                                            </tr>\n
# 1                                             <tr>\n
# 2          <td id="L2" class="blob-num js-line-nu...
# 3          <td id="LC2" class="blob-code blob-cod...
# 4                                            </tr>\n

# %% [markdown]
# #### Part A
#
# Find out where the state is stored inside the state column values and create a new column "state_cleaned" that only has the statename
#
# **Bonus:** Try to do this with a lambda function

# %%
# List of unique states included
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %% [markdown]
# #### Part B
#
# Do the same thing with the region column, this time naming the new column "region_cleaned"

# %%
# Final Result of both parts
towns[["state_cleaned","region_cleaned"]]
# Out:
#      state_cleaned              region_cleaned
# 0          Alabama
# 1          Alabama
# 2          Alabama
# 3          Alabama  Auburn (Auburn University)
# 4          Alabama
# ...            ...                         ...
# 2341       Wyoming
# 2342       Wyoming
# 2343       Wyoming
# 2344       Wyoming
# 2345       Wyoming
#
# [2346 rows x 2 columns]

# %% [markdown]
# ## Question 2
#
# Next, we have a dataframe with information on books.  This is a messy dataset, so let's only focus on the "Date of Publication" column.  Most of the time, we have a single date.  However, there are a lot of exceptions to this (we can see one below).  Clean up this column so that we have the earliest date listed as the only date.  **Note that this will take a lot of trial and error!!!**
#
# **Hint:** Once every date has been completed, you'll be able to convert the datatype to "int" without error

# %%
books = pd.read_csv("../data/books.csv")[["Date of Publication"]]

# We won't need to worry about missing dates for this exercise
books.dropna(inplace=True)


books.head()
# Out:
#   Date of Publication
# 0         1879 [1878]
# 1                1868
# 2                1869
# 3                1851
# 4                1857

# %%
def clean_dates(s):

# %%
books["Earliest Date"] = books["Date of Publication"].apply(clean_dates)
# Out:
#      Date of Publication Earliest Date
# 0            1879 [1878]          1878
# 1                   1868          1868
# 2                   1869          1869
# 3                   1851          1851
# 4                   1857          1857
# ...                  ...           ...
# 8282                1838          1838
# 8283            1831, 32          1831
# 8284           [1806]-22          1806
# 8285                1834          1834
# 8286             1834-43          1834
#
# [8106 rows x 2 columns]

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.min_rows', 100)

# %%
books[books["Date of Publication"].apply(lambda x:False if len(x)==4 and x.isnumeric() else True)]
# Out:
#      Date of Publication Earliest Date
# 0            1879 [1878]          1878
# 13           1839, 38-54          1838
# 16               1860-63          1860
# 23    1847, 48 [1846-48]          1846
# 24               [1897?]          1897
# 25               [1897?]          1897
# 34              [1894-96          1894
# 37                [1885]          1885
# 38               [1860?]          1860
# 46                [1833]          1833
# 56               [1817.]          1817
# 62          1886, [1885]          1885
# 63                [1834]          1834
# 64               1852-63          1852
# 66              1866, 76          1866
# 84     [1860,] 1861-1863          1860
# 85                [1872]          1872
# 88               [1874.]          1874
# 89        1858 [1851-58]          1851
# 92           1857 [1856]          1856
# 93                [1896]          1896
# 111              1812-15          1812
# 121             1884, 85          1884
# ...
